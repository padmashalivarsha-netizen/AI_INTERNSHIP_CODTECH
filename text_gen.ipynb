# %% [markdown]
# <a href="https://colab.research.google.com/github/padmashalivarsha-netizen/AI_INTERNSHIP_CODTECH/blob/main/text_gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch -q

# %%
from transformers import pipeline, logging

logging.set_verbosity_error()

generator = pipeline(
    "text-generation",
    model="gpt2"
)

prompt = input("Enter a topic or starting sentence:\n\n")

result = generator(
    prompt,
    max_new_tokens=150,
    temperature=0.6,
    top_k=50,
    top_p=0.95,
    repetition_penalty=1.3,
    do_sample=True
)

generated_text = result[0]['generated_text']

print("\n===== USER PROMPT =====\n")
print(prompt)

print("\n===== GENERATED TEXT =====\n")
print(generated_text)

print("\nGenerated Word Count:", len(generated_text.split()))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a topic or starting sentence:
#
# future of machine learning
#
# ===== USER PROMPT =====
#
# future of machine learning
#
# ===== GENERATED TEXT =====
#
# future of machine learning and AI, but also to understand the nature of machines.
# ...
