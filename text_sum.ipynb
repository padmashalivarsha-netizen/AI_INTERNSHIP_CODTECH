# %% [markdown]
# <a href="https://colab.research.google.com/github/padmashalivarsha-netizen/AI_INTERNSHIP_CODTECH/blob/main/text_sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch sentencepiece -q

# %%
from transformers import pipeline
summarizer = pipeline(
    "summarization",
    model="sshleifer/distilbart-cnn-12-6"
)
text = input("Enter a lengthy article:\n\n")
summary = summarizer(
    text,
    do_sample=False,
    truncation=True
)
summary_text = summary[0]['summary_text']
original_word_count = len(text.split())
summary_word_count = len(summary_text.split())
print("\n ==== ORIGINAL TEXT ==== \n")
print(text)
print("\nOriginal Word Count:", original_word_count)
print("\n **** SUMMARIZED TEXT ****\n")
print(summary_text)
print("\nSummary Word Count:", summary_word_count)
# Out:
# Enter a lengthy article:
#
# ...
